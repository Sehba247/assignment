# %% [markdown]
# #**Theoretical** **Answers**
#
# ---
#  ANS-1
#  - A Compiler takes the program in one go .It translates the whole source code into machine code at once.
#  - An Interpreter translates and executes the source code line by line during runtime.
#
# ANS-2
#  - Exceptional Handling in Python is a process of handling or resolving the errors that occur during the runtime of a program.
#
# ANS-3
#  - Finally block is used to define the code that will always execute ,regardless of whether an exception occured or not.
#
# ANS-4
# - Logging in Python is a module which allows to record  important information about program's execution.It allows to write status messages to a file or any other output stream.
#
# ANS-5
#
#  - The ______del__ method in Python allows us to define important action  to be taken when an object is garbage colected or destroyed.
#
# ANS-6
#
#  - Import  imports an entire code library while from__import import a specific member of the library.
#
# ANS-7
#
#  - Python allows us to add multiple exceptions in a single except block by specifying them as a tuple.
#
# ANS-8
#
#  - The with statement in python ensures that no file is accidentally leave to be open. With statement is a replace of commomnly used try-finally error handling statements.
#
# ANS-9
#
#  - Multithreading is a  task or an operation that can execute multiple threads at the same time .Threading module offers api that is used for multithreading purpose in python.
#  - Multiprocessing in python is an effective mechanism for memory management .It enables us to create bypass program the GIL and make optimum use of CPU core.
#
# ANS-10
#
#  - It helps debug errrors easily and is used to save info on warnings ,errors and events .
#
# ANS-11
#
#  -  Python memory management is the process of allocating and dealing with memory so that your program can run efficiently.
#
# ANS-12
#
#  - In Python exception handling in Python is managed using try, except, else and finally blocks. The try block contains the code that might raise an exception.If an exception occurs within the try block , the code execution jumps  to corresponding except bliock to handle the exception.The else block contains code that's executed if no exception occur within the try block.and the finally block contain code that is always executed regardless of exception is raised or not.
#
# ANS-13
#
#  - Memory Mangement in python is essential for ensuring efficient allocation and deallocation for memory of ojects .It is necessary for creating robust and secure applications .
#
# ANS-14
#
#  - The try block tests a block of code for errors. The except block handles the errors or exceptions arised in try block.
#
# ANS-15
#
#   - In python , collector keeps track of the number of objects allocations and deallocations since the last collection.When the number of allocations minus the number of deallocations exceeds threshhold0 ,garbage collection starts.
#
# ANS -16
#
#  - The else block executes code when their is no error .
#
# ANS-17
#
#  - DEBUG, INFO, WARNING, ERROR AND CRITICAL are the common logging levels of Python.
#
# ANS-18
#
#  - The os.fork() method forks a child process . The os.fork() creates two processes a parent process and a child process .os.fork() copies everything in the current process using unix's forking .Multiprocessing involves creating multiple separate processeseach with its own memory space and Python interpreter.
#
# ANS-19
#
#  - Closing files in Pythonis crucial to prevent resource leaks and ensure that changes are saved .
#
# ANS-20
#
#  - Read() method is used to read a specified nbumber of characters from a file or input stream while readline() method is useed to rad a single line from a file or input stream.
#
# ANS-21
#
#  - Logging module in Python allows writing status messages to a file or output streams .It records events that occur during program execution.
#
# ANS-22
#
#  - The os module in Python has methods which are used for interacting with the operating system like creating files and directories ,management of file and directories etc.
#
# ANS-23
#
# - Garbage collection overhead ,memory leaks ,reference counting limitations etc are the challenges related to memory management in Python.
#
#
# ANS-24
#
#  - We can raise an exception in Python by using the raise keyword .
#
# ANS-25
#
# - Multithrreading improves the performance of applications and responsiveness by running the task simultaneously and running a thread after a task is blocked respectively.

# %%
#Practical Answers





#ANS-1

 #  Create a file using "w" mode .
 # Open the file example.txt in write mode by using the open() function by specifying the mode of file and its name with .txt extension in the parenthesis.
 # the write () mrthod insert the sting into the created text file ."""
# Out:
#   File "<ipython-input-1-1623f6bca7b3>", line 5
#     ---
#        ^
# SyntaxError: invalid syntax

# %%
#ANS2
#ANS-2
L=["SEHBA\n","MUMTAZ\n"]
file1=open("example.txt","w")
file1.writelines(L)
file1.close()

file1=open("example.txt","r")
lines=file1.readlines()
print(file1.readlines())

count=0
for line in lines:
    count+=1
    print("line{};line{}".format(count,line.strip()))
# Out:
# []
# line1;lineSEHBA
# line2;lineMUMTAZ

# %%
#ans3
#In this case file not found error is raised .To handle this we can use a try-except block .

# %%
#ANS4
with open("sehba.txt","r") as file:
    with open("sehba.txt","w") as output:
        for line in file:
            output.write(line)

# %%
#ANS5
#Using if-else condition or by using try-except block we can handle zerodivision error.

# %%
import logging

#ANS6
numerator = 10
denominator = 0

# %%
#ans7
#logger.info(msg) log a message with level info .
#logger.warning(msg)will log a message with a level warning on this logger.
#logger.error(msg)will log a message with a level error .

# %%
#ans8
try:
  file=open("nonexistent_file.txt","r")
  content=file.read()
  print(content)
  file.close
except FileNotFoundError:
  print("file not found")
# Out:
# file not found

# %%
#ans9
with open("example.txt","r") as file:
   lines=[line.strip() for line in file]
print(lines)

# %%
#ans10 we can do this as follows  by using 'a' mode
file1=open("example.txt","w")
L=["this is delhi\n","this is mumbai\n"]
file1.writelines(L)
file1.close()
file1=open("myfile.txt","a")
file1.write("today\n")
file1.close()
file1=open("myfile.txt","w")
file1.write("tomorrow\n")
file1.close()

file1=open("myfile.txt","r")
print(file1.read())
print(file1.close())
# Out:
# tomorrow
#
# None

# %%
#ans12
dict={"these":1 ,"are":2,"words":3}
while True:
  try:
    w =input("enter a word")
  except:
    print("enter a valid word")
  else:
    print(dict[w])
# Out:
# Streaming output truncated to the last 5000 lines.
# enter a valid word
# enter a valid word
# enter a valid word
# enter a valid word
# enter a valid word
# enter a valid word
# enter a valid word
# enter a valid word
# enter a valid word
# enter a valid word
# enter a valid word
# enter a valid word
# enter a valid word
# enter a valid word
# enter a valid word
# enter a valid word
# enter a valid word
# enter a valid word
# enter a valid word
# enter a valid word
# enter a valid word
# enter a valid word
# enter a valid word
# enter a valid word
# enter a valid word
# enter a valid word
# enter a valid word
# enter a valid word
# enter a valid word
# enter a valid word
# enter a valid word
# enter a valid word
# enter a valid word
# enter a valid word
# enter a valid word
# enter a valid word
# enter a valid word
# enter a valid word
# enter a valid word
# enter a valid word
# enter a valid word
# enter a valid word
# enter a valid word
# enter a valid word
# enter a valid word
# ...

# %%
#ans 13 Using os . os.path.isfile()method in python is used to check whether a file exist or not.
