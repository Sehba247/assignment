# %% [markdown]
# #Theoretical Questions
#
# ---
#
# 1-What is numpy and why is it widely usedin Python?
#
#  - Numpy stands for numerical Pyhton .It is a Python library used for working with arrays. It provide a collection of high level mathematical functions to operate on these arrays.umpy is widely used in  Python due to its efficiency versatility and strong support for numerical and scientific computing.
#
# 2- How  does broadcasting work in Numpy?
#   - Broadcasting automatically adjusts the smaller array to match the shape of the larger array by replicating its values along with necessary dimensions .
#   there are specific rules on which broadcasting works in Python which are as follows:
#
#   i- It ensures the arrays have the same no. of dimensions.
#
#   ii-If Arrays have different numbers of dimensions ,the smaller array is left padded with ones.
#
#   iii-Two dimensions are compatible if they are equal or one of them is one.
#   If these conditions are not met a value error is raised.
#
# 3- What is a Pandas dataframe?
#  - Panda dataframe is a way to represent and work with tabular data.It is a two dimensional data structure like a 2 dimensional array or a table with rows and columns.
#
# 4-Explain the use of groupby() method in Pandas?
#  - The groupby() method in pandas is a tool that helps you to organize data into groups based  on certain criteria, like the value in a column.
#
# 5- Why is seaborn preferred for statistical visualization?
#  - Seaborn is preferred because it makes easier understanding of data distributions and relationship between them.It offers attractive default styles and color palettes allowing for quick creation of professional looking visualization. It provides high level interface and statistical functiopns also for adding insights to visualization.
#
# 6- What are the differences between numpy arrays and python lists?
# - Numpy arrrays are homogenous while the Python lists are hetrogenous.Numpy arrays are of fixed size while python arrays are dynamic .
# lists have less mathematical functionality as compared to numpy arrays.
# Arraysare optimized for large datasets and numerical computation while python lists are more flexible for general purpose tasks.
#
# 7- What is a heatmap , when should it be used?
#  - A heatmap is a way to represent data points in a data set in a visual manner
#  .All heatmaps share one thing in common -  they use different colors or different shades of the same color to represent different values.Heatmaps are particularly used when we want to see areas og higher and loer concentration in the distribution of data. They use warmer color for higher values and cooler colors for lower values.They are  used to represent data distribution across map , to visualize market trends etc.
#
# 8- What does the term "vectorized operation" mean in Numpy?
#
#  - In numpy , a vectorised operation means performing mathematical or logical functions on entire arrays at once rather than iteratiing through each item of the array.
#
# 9- How does matplotlib differ from plotly ?
#  - Matplotlib focuses on crating variety of static and interactive plot ,including 2d and 3d visualizations but it is more complex to use for simple plots and not ideal for web based appliccations while plotly focuses on creating web based visualization including maps and dashboards.
#
# 10- What is the significance of hierarchial indexing in Pandas?
#  - It is important in Pandas beacause it enables the representation and manipulation of data with multiple lelels of indexing with a dataframe or series .
#
# 11- What is the role of seaborn's pairplot ()function?
#  - Seaborn's pairplot() function visualizes relationship between multiple variables in a dataset.It creates a matrix of scatter plots where each plot shows the relationship between two variables.
#
# 12- What is the purpose of describe() function in Pandas?
#  - The describe() function in Pandas is used to generate descriptive statistics of a dataframe or series.It is a convenient way to get the data overview in pandas.
#
# 13- Why is handling missing data important in pandas?
#  - In Pandas missing values can cause problems during data processing and analysis . These gaps in data can lead to incorrect analysis and misleading conclusions , that's why it is necessary to handle missing values.
#
# 14- What are the benefits of using plotly for data  visualization?
#
#  -  Ease of use and interactivity ,wide range of data types ,web integration and extensive customization enabling users to tailor the appearance of their visualization including colors, fonts and layouts,Open source etc are some of the benefits plotly offers to its users for data visualization.
#
# 15- How does numpy handles multidimensionl arrays?
#
#  - The ndarray efficiently handles multidimensional arrays .It uses metadata including shape and strides to interprwet the data as a multidimensional array.The shape defines the size of each dimension whilestrides define thw numer of bytesto each step in each dimension. This Approach enables various operations su7ch as slicing ,reshaping, and transposing without moving the und3erlying data.
#
# 16- What is the role of bokeh in data visualization?
#
#  - Bokeh is a data visualization library in python that provides high performance interactive charts and plots.
#
# 17- Explain the difference between apply and map in Pandas?
#
#  - The apply() method can be applied both to series and dataframes where a function can be applied to both series and individual elements based on the type of function provided. The map() method only works on a panda seriues whete the type of operation to be applied depends on the arguments passed as
#  a function ,dictionary or list.It  goes through each value one by one and applies a function but it only works on asingle column.If you need to apply fuction across multiple columns or rows ,then apply() is your  best friend.
#
#  18- What are some advanced features of numpy?
#
#   - Broadcasting, universal functions(ufuncs),fancy indexing , boolean indexing , matrix operations etc are some of several advanced features of numpy beyond basic array msnipulation.
#
# 19- How does pandas simplify time series analysis ?
#
#  - Pandas simplifies time series analysis  by providing specislised data structure and functions designed for handling time stamped data through datetime indexing, resampling, time shifting , rolling,data parsing .
#
# 20- What is the role of pivot table in python?
#   - A pivot table in pandas is a quantitative table that summarises a large dataframes, such as a large dataset.It is a component of data processing..In Pandas pivot_table() function creates spreadsheet style pivot table.
#
# 21- Why is numpy's array slicing faster than python list slicing?
#  - Numpy array slicing is faster than python list slicing due to how data is stored and handled in memory and the way operations are implemented. Numpy arrays store elements of the same data type contiguously in memory , enabling efficient access and vectorised operations. python lists on the other hands can store hetrogenous data types leading to more overhead and slower accesss time.
#
# 22- What are somde common use cases for Seaborn?
#  - Seaborn is particularly used for tasks like exploratory data analysis , data storytelling and visualising results from statistical models.
#  -

# %%
#practical
#Ans1
#The np.array() fuction creates a numpy array.
import numpy as np
arr=np.array([[1,2,3],
             [4,5,6]])
row_sum=np.sum(arr,axis=1)
print(row_sum)
# Out:
# [ 6 15]

# %%
#ans2
import pandas as pd
data = {'col_1':[1,2,3,4,5],
        'col_2': [6,7,8,9,10]}
df=pd.DataFrame(data)
mean_col_1=df['col_1'].mean()
print(mean_col_1)
# Out:
# 3.0

# %%
#ans3
import matplotlib.pyplot as plt
x = [1,2,3,4,5]
y=[2,4,1,3,5]
plt.scatter(x,y)
plt.xlabel('x-axis')
plt.ylabel('y-axis')
plt.title('scatter plot')
plt.show()

# %%
#ans4
import seaborn as sns
data = {'col_1':[1,2,3,4,5],
        'col_2': [6,7,8,9,10]}
df=pd.DataFrame(data)
corr_matrix=df.corr()
sns.heatmap(corr_matrix,annot=True ,cmap="coolwarm",square=True)
plt.show()

# %%
#ans5
import plotly.graph_objects as go
categories=['category A','category B','category C']
values=[10,20,30]
fig=go.Figure(data=[go.Bar(x=categories,y=values)])
fig.update_layout(title_text='Bar Chart')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
#ans6
import pandas as pd
df=pd.DataFrame({'name':
                 ['Sehba','Sabiha','Ayesha'],
                 'Age':['21','45','26']})
print(df)
#now adding new column hobbies
df['Hobbies']=['reading','playing','cooking']
print(df)
# Out:
#      name Age
# 0   Sehba  21
# 1  Sabiha  45
# 2  Ayesha  26
#      name Age  Hobbies
# 0   Sehba  21  reading
# 1  Sabiha  45  playing
# 2  Ayesha  26  cooking

# %%
#ans7
import numpy as np
arr=np.array([[1,2,3],[4,5,6]])
arr2=np.array([[7,8,9],[10,11,12]])
out_arr=np.multiply(arr,arr2)
print(out_arr)
# Out:
# [[ 7 16 27]
#  [40 55 72]]

# %%
#ans8
import matplotlib.pyplot as plt
x=[1,2,3,4,5]
y1=[2,4,1,3,5]
y2=[3,1,4,2,5]
y3=[1,3,5,4,2]
plt.plot(x,y1,label='line1',marker='o')
plt.plot(x,y2,label='line2',marker='x')
plt.plot(x,y3,label='line3',marker='^')
plt.legend()
plt.xlabel('x-axis')
plt.ylabel('y-axis')
plt.title('multiple lines  plot')
plt.show()

# %%
#ans9
import pandas as pd
import numpy as np
data={'col1':[1,5,10,15,20],
      'col2':[2,4,6,8,10]}
df=pd.DataFrame(data)
threshold=10
column_name='col1'
filtered_df=df[df[column_name]>threshold]
print(df)
print(filtered_df)
# Out:
#    col1  col2
# 0     1     2
# 1     5     4
# 2    10     6
# 3    15     8
# 4    20    10
#    col1  col2
# 3    15     8
# 4    20    10

# %%
#ans10
import seaborn as sns
data=sns.load_dataset('iris')
sns.histplot(data=data,x='sepal_width',bins=20,color='green',kde=True)
plt.xlabel('sepal_width')
plt.ylabel('frequency')
plt.show()

# %%
#ans11
import numpy as np
p=[[1,2],[2,3]]
q=[[4,5],[6,7]]
print("matrixp :")
print(p)
print("matrixq :")
print(q)
result=np.dot(p,q)
print("result :")
print(result)
# Out:
# matrixp :
# [[1, 2], [2, 3]]
# matrixq :
# [[4, 5], [6, 7]]
# result :
# [[16 19]
#  [26 31]]

# %%
#ans12
import pandas as pd
data={'col1':[1,2,3,4,5,8,9],'col2':[6,7,8,9,10,11,12]}
df=pd.DataFrame(data)
print(df)
df.to_csv('output.csv',index=False)
df=pd.read_csv('output.csv')
print(df.head())
# Out:
#    col1  col2
# 0     1     6
# 1     2     7
# 2     3     8
# 3     4     9
# 4     5    10
# 5     8    11
# 6     9    12
#    col1  col2
# 0     1     6
# 1     2     7
# 2     3     8
# 3     4     9
# 4     5    10

# %%
#ans13
import plotly.express as px
df=px.data.iris()
fig=px.scatter_3d(df, x='sepal_length',y='sepal_width',z='petal_width', color='species')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...
